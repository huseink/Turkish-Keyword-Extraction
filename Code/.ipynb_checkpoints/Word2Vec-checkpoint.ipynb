# %%
from gensim.models.word2vec import LineSentence
from gensim.models import Word2Vec
import pandas as pd
import nltk
import xml.etree.ElementTree as ET
import os
import gensim

# %%
path = '../Stemming/Makale Kokleri/Biyoloji.xml'
ozetceler = []
tree = ET.parse(path)
root = tree.getroot()
for ozetce in root:
    ozetce = ozetce.text
    ozetce = str(ozetce)
    ozetceler.append(ozetce)

# %%
print(ozetceler)
# Out:
# [' bu araştırmak 2002 ve 2003 yıl hidrografik açı bir havza özellik göstermek yaklaşık 1900  km2  lik bir  yüzölçüme sahip Erzurum un Tortum ve Uzundere ilçe içeri yer alan Tortum çay havza NDA yapmak çalışmak alan  fitocoğrafik konum itibarî ile  A8 ve  A9 kare içeri yer almak araştırmak alan aynı zaman Turan ve Sibirya  floristik bölge kesişim nokta araştırmak amaç yöre kent ve kır mekân peyzaj planlamak ve tasarım çalışmak kullanmak doğal odun bitki belirlemek araştırmak alan 25 familya ait 54 odun bitki tür tespit etmek ayrıca yetişmek ortam özellik ile bitki  fenolojik ve morfolojik özellik belirlemek yapmak değer sonuç bu bitki tür 30 un peyzaj onarım çalışmak 28 inmek karayolu kenar orta refüj ve otopark planlamak 19 un kaya ve kuru duvar bahçe 9 un yer örtmek olmak ve 39 un estetik özellik dolayı kullanmak sonuç varmak  ', ' Azerbaycan In dağlık bölge yaymak göstermek 60 familya ve 194 cins ait 321 fayda bitki rastlamak araştırmak yıl ara gerçek bu bitki 124  ü süs 60 I tıbbî 54  ü gıda 42 si  eterik yağ 39 U bal vermek 19 U vitamin 18  i zehir 17 si boya 11  i yem 6 sımak kauçuk ve 1 adet sabun içerik olmak belirlemek alan rastlamak bitki toplam sayı  i  Asteraceae  Lamiaceae  Liliaceae  Rosaceae  Apiaceae ve  Primulaceae familya  i ise  Thymus  Nepeta  Primula  Achillea  Pyretrum ve  Polygonum cins ait olmak  taksonlardır bu bitki  ü 231  takson ot bu da 56 I çok yıllık U tek yıllık  ü ise iki yıllık yıllık ve yıllık U soğan  i 62  takson odun bu I çalı  i ağaç  i yarı çalı gövde 2  rizomlu 3 ve 1 bitki rastlamak alan 34 endemik türe rastlamak bu 8  i Azerbaycan da 26 sımak ise Kafkasya da yaymak göstermek  ', ' bu araştırmak Zonguldak il sınır iç gerçek haziran aralık 2004 yıl ara araştırmak alan 119 istasyon 473 bitki örnek toplamak bu örnek değer sonuç 105 familya ait 294 cins 366 tür 53 alt tür 31 varyete ve  kültivar saptamak bu 473  taksondan 85  i A4 kare ilk kez belirlemek teşhis yapmak tür 16 sımak  Pteridophyta  divizyosuna 457 si ise  Spermatophyta  divizyosuna ait  Spermatophyta  divizyosuna ait  taksonların 37 si  Gymnospermae 420 si ise  Angiospermae alt  divizyosuna ait  Angiospermae alt  divizyosundan 420 tür  Dicotyledonae 33 tür ise  Monocotyledonae sınıf ait alan endemik tür sayı 7  dir tanı yapmak tür 90  nı element 37 si Akdeniz element 3  ü element ve 346 sımak ise çok bölge veya  fitocoğrafik bölge bilmek en çok tür içermek familya sıra  Rosaceae 38 tür  Leguminosae 34 tür  Compositae 26 tür  Labiatae 20 tür  Pinaceae 18 tür  Scrophulariaceae 16 tür en çok tür içermek cins  Quercus 9 tür  Mentha 7  species  Campanula 6 tür  Cupressus 5 tür  Verbascum 3 tür  ', '  Minuartia  nifensis Mc Neill  Caryophyllaceae in yıl ara gerçek çalışmak ile bu tür sınır yaymak neden belirlemek çalışmak bu amaç bitki yaşamak çevre koşul ile üremek biyoloji araştırmak  nifensis Mc Neill  Caryophyllaceae Türkiye flora  sında  Nif dağ  ndaki tek  lokaliteden kaydetmek arazi çalışmak sonuç ilk  lokalitenin yaklaşık 1 Km Güney Batı yeni bir  lokalite tanımlamak  GIS ve örneklem  metodları kullanmak bu tür yaymak alan  km2 ve alan bulunmak birey sayı 3308 olmak hesaplamak bu tür Iucn 1994 kriter göre hassas olmak belirlemek çalışmak sonuç tür Iucn 2001 kriter göre kritik tehlike alt Cr  B2ab  ii  iii olmak önermek ayrıca ilk defa olmak bu tür hermafrodit ve dişi çiçek birey olmak saptamak araştırmak sıra el etmek veri hermafrodit birey  kendikendine veya böcek dişi birey sadece böcek toz göstermek toz deneme ayrıca tüm Çiçek potansiyel olmak tohum oluşmak göstermek ve  sporogenez toz ve zigot sonra dönem herhangi bir olumsuz oluşmak göstermek  ovül oran hermafrodit Çiçek 24 ve dişi Çiçek 17 ve üremek başarı düşük bulunmak bu da doğa Anter ve  stigmalar ara yetersiz polen transfer dayanmak düşünmek  ', ' orman yetişmek ortam sınıf ve haritalamak bitki tür yaymak ile çevre faktör ara ilişki belirlemek önem bu sebep bitki tür itibarî örnek alan grup ve bu grup gösterge bitki orman yetişmek ortam sınıf için bağımlı değişken ...

# %%
kelimeler = []
for i in ozetceler:
    kelimeler.append(i.split())

# %%
print(len(kelimeler))
# Out:
# 172

# %%
model =Word2Vec(kelimeler, vector_size =100,window = 10, min_count= 1, sg = 0)

# %%
model.wv["Türkiye"]
# Out:
# array([-0.41671932,  0.47613162,  0.1409405 ,  0.1226564 ,  0.00393216,
#        -0.69441617,  0.29156217,  1.2431939 , -0.33014727, -0.2651181 ,
#        -0.18012302, -0.7941699 , -0.20315836,  0.15475474,  0.20612825,
#        -0.4222988 ,  0.06668755, -0.50283635, -0.22384381, -0.96256566,
#         0.26756525,  0.18680193,  0.46251494, -0.27758244, -0.22043818,
#         0.16092129, -0.36315912, -0.45659405, -0.41984633,  0.03437618,
#         0.69851404,  0.06544454,  0.2569028 , -0.34207153, -0.19278325,
#         0.58229715,  0.17279609, -0.3497832 , -0.30562958, -1.0293862 ,
#         0.20160733, -0.5386866 , -0.1240896 ,  0.12880547,  0.45313996,
#        -0.13149625, -0.59264946, -0.11189535,  0.28761953,  0.32758686,
#         0.18791282, -0.5045251 , -0.06656642, -0.24303436, -0.17628714,
#         0.25656423,  0.57072693, -0.0486279 , -0.41843516,  0.21145295,
#         0.07331949,  0.23875631, -0.17886645, -0.03574683, -0.47901785,
#         0.6848962 ,  0.02630534,  0.4205193 , -0.63153285,  0.6210429 ,
#        -0.3033217 ,  0.47328547,  0.62016535, -0.06914433,  0.74526125,
#         0.12266838,  0.06520276, -0.06971862, -0.5310642 ,  0.1312868 ,
#        -0.10603381, -0.12342027, -0.5145594 ,  0.76584125, -0.24856079,
#        -0.05700828,  0.18886526,  0.47748595,  0.7130582 ,  0.22528243,
#         0.5023879 ,  0.6269322 ,  0.16600792,  0.0957106 ,  0.8931695 ,
#         0.34312317,  0.15121649, -0.5205718 ,  0.09995519,  0.02833084],
#       dtype=float32)

# %%
model.wv.most_similar("Türkiye")
# Out:
# [('olmak', 0.9998560547828674),
#  ('ve', 0.9998385310173035),
#  ('subsp', 0.99983811378479),
#  ('tür', 0.9998347163200378),
#  ('en', 0.9998296499252319),
#  ('bu', 0.9998226761817932),
#  ('çalışmak', 0.9998139142990112),
#  ('ile', 0.9998123645782471),
#  ('var', 0.9998117089271545),
#  ('fark', 0.9998114705085754)]

# %%
model.save("word2vec.model")

# %%
model2 = Word2Vec.load("word2vec.model")

# %%
model2.wv.most_similar("Türkiye")
# Out:
# [('olmak', 0.9998560547828674),
#  ('ve', 0.9998385310173035),
#  ('subsp', 0.99983811378479),
#  ('tür', 0.9998347163200378),
#  ('en', 0.9998296499252319),
#  ('bu', 0.9998226761817932),
#  ('çalışmak', 0.9998139142990112),
#  ('ile', 0.9998123645782471),
#  ('var', 0.9998117089271545),
#  ('fark', 0.9998114705085754)]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# %%
def closestwords_tsneplot(model, word):
    word_vectors = np.empty((0,100))
    word_labels = [word]
    close_words = model.wv.most_similar(word)
    word_vectors = np.append(word_vectors, np.array([model.wv[word]]), axis = 0)
    
    for w, _ in close_words:
        word_labels.append(w)
        word_vectors = np.append(word_vectors, np.array([model.wv[w]]), axis = 0)
    tsne = TSNE(random_state = 0)
    Y = tsne.fit_transform(word_vectors)
    x_coords = Y[:,0]
    y_coords = Y[:,1]
    plt.scatter(x_coords, y_coords)
    
    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy = (x,y), xytext = (5, -2), textcoords = "offset points")
    
    plt.show()

# %%
closestwords_tsneplot(model2,"Türkiye")

# %%
closestwords_tsneplot(model2,"araştırmak")

# %%
closestwords_tsneplot(model2,"havza")
