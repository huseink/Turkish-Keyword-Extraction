# %%
from gensim.models.word2vec import LineSentence
from gensim.models import Word2Vec
import pandas as pd
import nltk
import xml.etree.ElementTree as ET
import os
import gensim

# %%
path = '../Stemming/Makale Kokleri/biyomedikal.xml'
ozetceler = []
tree = ET.parse(path)
root = tree.getroot()
for ozetce in root:
    ozetce = ozetce.text
    ozetce = str(ozetce)
    ozetceler.append(ozetce)

# %%
print(ozetceler)
# Out:
# [' bu çalışmak elektrokardiyografi Ekg aritmi sınıf için yeni bir yöntem olmak kompleks dalga dönüşüm  KDD ve kompleks değer yapay sinir ağı  KDYSA yapı önermek öneri yapı fark seviye  KDD ile Ekg data ait özellik çıkartmak boyut azaltım yapmak ve daha sonra bu özellik vektör kullanmak istatistiki dört özellik maksimum değer minimum değer ortalama değer standart sapmak el etmek  KDYSA ya girişmek olmak sunmak çalışmak kullanmak data set  ECG aritmi veri taban seçmek normal sinüs ritm sağ dal blok sol dal blok  atrial  fibrilasyonu ve  atrial  flutter dan oluşmak 5 fark aritmi çeşit kullanmak oluşmak test ve eğitim set yer alan ve 200 Örnek oluşmak her bir örüntü seviye  KDD için 100 seviye  KDD için 50 ve seviye  KDD için 25 örnek düşürmek seviye  KDD kullanmak yapmak sınıflamak sonuç aritmi 100 doğru oran ile sınıf görmek bu seviye için gerekli sınıflamak süre saniye olmak el etmek  ', ' bu çalışmak elektrokardiyografi aritmi sınıf için gerçek Bulanık kümelemek sinir ağı  T2BKSA yapı sunmak Bulanık kümelemek sinir ağı kümelemek ve sınıf aşama oluşmak  kaskat bir yapı  T2BKSA yapı aynı sınıf ait örüntü içeri sınıf en iyi temsil etmek örüntü seçmek işlem kapsamak kümelemek aşama Bulanık kümelemek  T2BCO algoritma ile gerçek  T2BCO kümelemek algoritma kullanmak amaç eğitim örüntü set optimize etmek sinir Ağın sınıf hata düşürmek Bulanık kümelemek algoritma ile her sınıf için ayrı ayrı el etmek küme merkez oluşmak yeni eğitim set yapay sinir Ağın giriş oluşmak yapay sinir ağı geri yayılım algoritma kullanmak eğitmek öneri yapı normal sinüs ritm sinüs  bradikardisi sinüs aritmi sağ dal blok ve sol dal blok sinyal içermek 5 sınıf ait Ekg sinyal sınıf kullanmak çalışmak kullanmak veri  Physionet veri taban el etmek  ECG  Arrhythmia Database e ait veri gerçek uygulamak sonuç öneri  T2BKSA yapı Ekg aritmi 100 doğru sınıf oran ile sınıf  ', ' Ekg elektro kardiyogram kayıt yazılım taban uzman sistem tarafından yorumlamak 1960  lı yıl dayanmak son 20 yıl bu konu birçok teknik üzeri çalışmak yapmak fakat güç tahmin yetenek olmak inanç sebep medikal tanımak destek sistem uygulamak kullanmak en popüler yöntem  YSA yapay sinir ağ olmak literatür öneri  YSA model çok karmaşık yazılım taban çözüm ve bu gerçek zaman çalışmak bu tür yapı donanım gerçeklemek ise ancak paha işlemci üzeri yapmak  YSA donanım gerçeklemek taşınmak ucuz cihaz üzeri oluşmak mümkün kılmak için  YSA giriş uygulamak Ekg işaret özellik sayı azalmak bu saye daha az sayı bilgi ile daha basit bir mimarî oluşmak mümkün olmak bu çalışmak  YSA  nın öğrenmek hata 5 gibi kabul etmek bir seviye tutmak  TBA temel bileşen analiz yöntem kullanmak Ekg girişmek işaret özellik sayı önem ölçü azalmak bu saye  8x2x1 boyut basit bir  Matlab  YSA Mode  FPGA alan program kapı dizi donanım üzeri  IEE 754 32 bit kayan nokta nümerik sayı format kullanmak gerçek  ', ' kalp hız değişken  KHD otonom sinir sistem parasempatik ve sempatik baskın hak bilgi vermek önem bir fizyolojik işaret parasempatik ve sempatik baskın alçak frekans af frekans  YF güç oran şekil tanımlamak ve  sempatovagal denge olmak ifade etmek bu çalışmak  ventriküler  taşiaritmi hasta  sempatovagal denge değer incelemek ve aynı hasta ait normal kayıt el etmek değer ile karşılaştırmak  Ventriküler  taşiaritmi kayıt en düşük ve en yüksek normal kayıt en düşük ve en yüksek  sempatovagal denge değer el etmek  ', ' ilk kez  Farwell ve  Donchin tarafından orta konu hecelemek paradigma genel anlam felç hasta çevre iletişim kurmak sağlamak bir beyin bilgisayar arayüz  BBA uygulamak bu uygulamak kullanmak bilgisayar ekran belli bir süre rastgele yanmak sönmek karakter odak gerekmek uygulamak ana problem odaklamak karakter sistem tarafından doğru tahmin etmek ve karakter doğru tahmin etmek süre oldukça önem bu çalışmak iki ayrı amaç var  P300 sinyal algılamak optimal frekans bant göz ön bulunmak kullanmak hecelemek paradigma sistem özel tepki incelemek ve ikinci olmak hecelemek paradigma sistem satır ve sütun yanmak kar kullanmak algı ara ...

# %%
kelimeler = []
for i in ozetceler:
    kelimeler.append(i.split())

# %%
print(kelimeler)
# Out:
# [['bu', 'çalışmak', 'elektrokardiyografi', 'Ekg', 'aritmi', 'sınıf', 'için', 'yeni', 'bir', 'yöntem', 'olmak', 'kompleks', 'dalga', 'dönüşüm', 'KDD', 've', 'kompleks', 'değer', 'yapay', 'sinir', 'ağı', 'KDYSA', 'yapı', 'önermek', 'öneri', 'yapı', 'fark', 'seviye', 'KDD', 'ile', 'Ekg', 'data', 'ait', 'özellik', 'çıkartmak', 'boyut', 'azaltım', 'yapmak', 've', 'daha', 'sonra', 'bu', 'özellik', 'vektör', 'kullanmak', 'istatistiki', 'dört', 'özellik', 'maksimum', 'değer', 'minimum', 'değer', 'ortalama', 'değer', 'standart', 'sapmak', 'el', 'etmek', 'KDYSA', 'ya', 'girişmek', 'olmak', 'sunmak', 'çalışmak', 'kullanmak', 'data', 'set', 'ECG', 'aritmi', 'veri', 'taban', 'seçmek', 'normal', 'sinüs', 'ritm', 'sağ', 'dal', 'blok', 'sol', 'dal', 'blok', 'atrial', 'fibrilasyonu', 've', 'atrial', 'flutter', 'dan', 'oluşmak', '5', 'fark', 'aritmi', 'çeşit', 'kullanmak', 'oluşmak', 'test', 've', 'eğitim', 'set', 'yer', 'alan', 've', '200', 'Örnek', 'oluşmak', 'her', 'bir', 'örüntü', 'seviye', 'KDD', 'için', '100', 'seviye', 'KDD', 'için', '50', 've', 'seviye', 'KDD', 'için', '25', 'örnek', 'düşürmek', 'seviye', 'KDD', 'kullanmak', 'yapmak', 'sınıflamak', 'sonuç', 'aritmi', '100', 'doğru', 'oran', 'ile', 'sınıf', 'görmek', 'bu', 'seviye', 'için', 'gerekli', 'sınıflamak', 'süre', 'saniye', 'olmak', 'el', 'etmek'], ['bu', 'çalışmak', 'elektrokardiyografi', 'aritmi', 'sınıf', 'için', 'gerçek', 'Bulanık', 'kümelemek', 'sinir', 'ağı', 'T2BKSA', 'yapı', 'sunmak', 'Bulanık', 'kümelemek', 'sinir', 'ağı', 'kümelemek', 've', 'sınıf', 'aşama', 'oluşmak', 'kaskat', 'bir', 'yapı', 'T2BKSA', 'yapı', 'aynı', 'sınıf', 'ait', 'örüntü', 'içeri', 'sınıf', 'en', 'iyi', 'temsil', 'etmek', 'örüntü', 'seçmek', 'işlem', 'kapsamak', 'kümelemek', 'aşama', 'Bulanık', 'kümelemek', 'T2BCO', 'algoritma', 'ile', 'gerçek', 'T2BCO', 'kümelemek', 'algoritma', 'kullanmak', 'amaç', 'eğitim', 'örüntü', 'set', 'optimize', 'etmek', 'sinir', 'Ağın', 'sınıf', 'hata', 'düşürmek', 'Bulanık', 'kümelemek', 'algoritma', 'ile', 'her', 'sınıf', 'için', 'ayrı', 'ayrı', 'el', 'etmek', 'küme', 'merkez', 'oluşmak', 'yeni', 'eğitim', 'set', 'yapay', 'sinir', 'Ağın', 'giriş', 'oluşmak', 'yapay', 'sinir', 'ağı', 'geri', 'yayılım', 'algoritma', 'kullanmak', 'eğitmek', 'öneri', 'yapı', 'normal', 'sinüs', 'ritm', 'sinüs', 'bradikardisi', 'sinüs', 'aritmi', 'sağ', 'dal', 'blok', 've', 'sol', 'dal', 'blok', 'sinyal', 'içermek', '5', 'sınıf', 'ait', 'Ekg', 'sinyal', 'sınıf', 'kullanmak', 'çalışmak', 'kullanmak', 'veri', 'Physionet', 'veri', 'taban', 'el', 'etmek', 'ECG', 'Arrhythmia', 'Database', 'e', 'ait', 'veri', 'gerçek', 'uygulamak', 'sonuç', 'öneri', 'T2BKSA', 'yapı', 'Ekg', 'aritmi', '100', 'doğru', 'sınıf', 'oran', 'ile', 'sınıf'], ['Ekg', 'elektro', 'kardiyogram', 'kayıt', 'yazılım', 'taban', 'uzman', 'sistem', 'tarafından', 'yorumlamak', '1960', 'lı', 'yıl', 'dayanmak', 'son', '20', 'yıl', 'bu', 'konu', 'birçok', 'teknik', 'üzeri', 'çalışmak', 'yapmak', 'fakat', 'güç', 'tahmin', 'yetenek', 'olmak', 'inanç', 'sebep', 'medikal', 'tanımak', 'destek', 'sistem', 'uygulamak', 'kullanmak', 'en', 'popüler', 'yöntem', 'YSA', 'yapay', 'sinir', 'ağ', 'olmak', 'literatür', 'öneri', 'YSA', 'model', 'çok', 'karmaşık', 'yazılım', 'taban', 'çözüm', 've', 'bu', 'gerçek', 'zaman', 'çalışmak', 'bu', 'tür', 'yapı', 'donanım', 'gerçeklemek', 'ise', 'ancak', 'paha', 'işlemci', 'üzeri', 'yapmak', 'YSA', 'donanım', 'gerçeklemek', 'taşınmak', 'ucuz', 'cihaz', 'üzeri', 'oluşmak', 'mümkün', 'kılmak', 'için', 'YSA', 'giriş', 'uygulamak', 'Ekg', 'işaret', 'özellik', 'sayı', 'azalmak', 'bu', 'saye', 'daha', 'az', 'sayı', 'bilgi', 'ile', 'daha', 'basit', 'bir', 'mimarî', 'oluşmak', 'mümkün', 'olmak', 'bu', 'çalışmak', 'YSA', 'nın', 'öğrenmek', 'hata', '5', 'gibi', 'kabul', 'etmek', 'bir', 'seviye', 'tutmak', 'TBA', 'temel', 'bileşen', 'analiz', 'yöntem', 'kullanmak', 'Ekg', 'girişmek', 'işaret', 'özellik', 'sayı', 'önem', 'ölçü', 'azalmak', 'bu', 'saye', '8x2x1', 'boyut', 'basit', 'bir', 'Matlab', 'YSA', 'Mode', 'FPGA', 'al ...

# %%
model =Word2Vec(kelimeler, vector_size =100,window = 10, min_count= 1, sg = 1)

# %%
model.wv["Türkiye"]
# Out:
# array([-0.02500289,  0.07468873,  0.08057125,  0.00220329, -0.08145781,
#        -0.10899966,  0.13763711,  0.327464  , -0.04607386, -0.23308529,
#        -0.15810697, -0.06302302,  0.10221843,  0.17351745,  0.1239394 ,
#        -0.08017015,  0.19428168, -0.04407557,  0.22582325, -0.26906618,
#         0.1633888 ,  0.08761963,  0.1850384 , -0.19398558, -0.18151717,
#        -0.03191451, -0.17398533,  0.00129963,  0.00679524,  0.12268579,
#         0.13981616, -0.11467479,  0.20331003, -0.04877918, -0.00097917,
#         0.29197648,  0.01520104, -0.09300749, -0.25311086, -0.09063045,
#         0.00858779, -0.14527345, -0.05672885, -0.04301971,  0.2098418 ,
#        -0.06797077, -0.19393705, -0.17031191,  0.10838935,  0.06455974,
#         0.15564883, -0.23304227, -0.1342214 , -0.04446738, -0.24695648,
#         0.1754091 ,  0.06172041, -0.07076031, -0.253762  ,  0.04102406,
#        -0.02632497,  0.10507149, -0.10864079,  0.01162243, -0.16201475,
#         0.13307571, -0.04500797,  0.12472322, -0.18262735,  0.2435931 ,
#        -0.00178932,  0.11128895,  0.08490037, -0.11609934,  0.25486642,
#        -0.09690029,  0.00714562, -0.03316461, -0.36829546,  0.10973455,
#        -0.23097639,  0.0293907 , -0.11379715,  0.36053374, -0.09589351,
#         0.14554597,  0.08250109,  0.23562513,  0.21870348,  0.09637029,
#         0.21329364, -0.01396048, -0.00763059, -0.07918399,  0.20965104,
#         0.12095203,  0.13228793, -0.09732084,  0.0194971 ,  0.02361434],
#       dtype=float32)

# %%
model.wv.most_similar("Türkiye")
# Out:
# [('merkez', 0.9985529184341431),
#  ('söz', 0.9985309839248657),
#  ('Nesibe', 0.9985271692276001),
#  ('tayin', 0.9985203742980957),
#  ('geçirmek', 0.9984499216079712),
#  ('kütüphane', 0.9984459280967712),
#  ('Mhz', 0.9984447956085205),
#  ('saymak', 0.9984368085861206),
#  ('PGG', 0.9983980655670166),
#  ('ilgi', 0.9983841180801392)]

# %%
model.save("word2vec.model")

# %%
model2 = Word2Vec.load("word2vec.model")

# %%
model2.wv.most_similar("oran")
# Out:
# [('kendi', 0.9968545436859131),
#  ('başarı', 0.9960213899612427),
#  ('sınıflamak', 0.9956672191619873),
#  ('geri', 0.9956164360046387),
#  ('kısıt', 0.9956112504005432),
#  ('birbiri', 0.9954581260681152),
#  ('tahmin', 0.9952295422554016),
#  ('genişlik', 0.9951973557472229),
#  ('öneri', 0.9950316548347473),
#  ('güvenmek', 0.994969367980957)]

# %%
print(kelimeler)
# Out:
# [['bu', 'çalışmak', 'elektrokardiyografi', 'Ekg', 'aritmi', 'sınıf', 'için', 'yeni', 'bir', 'yöntem', 'olmak', 'kompleks', 'dalga', 'dönüşüm', 'KDD', 've', 'kompleks', 'değer', 'yapay', 'sinir', 'ağı', 'KDYSA', 'yapı', 'önermek', 'öneri', 'yapı', 'fark', 'seviye', 'KDD', 'ile', 'Ekg', 'data', 'ait', 'özellik', 'çıkartmak', 'boyut', 'azaltım', 'yapmak', 've', 'daha', 'sonra', 'bu', 'özellik', 'vektör', 'kullanmak', 'istatistiki', 'dört', 'özellik', 'maksimum', 'değer', 'minimum', 'değer', 'ortalama', 'değer', 'standart', 'sapmak', 'el', 'etmek', 'KDYSA', 'ya', 'girişmek', 'olmak', 'sunmak', 'çalışmak', 'kullanmak', 'data', 'set', 'ECG', 'aritmi', 'veri', 'taban', 'seçmek', 'normal', 'sinüs', 'ritm', 'sağ', 'dal', 'blok', 'sol', 'dal', 'blok', 'atrial', 'fibrilasyonu', 've', 'atrial', 'flutter', 'dan', 'oluşmak', '5', 'fark', 'aritmi', 'çeşit', 'kullanmak', 'oluşmak', 'test', 've', 'eğitim', 'set', 'yer', 'alan', 've', '200', 'Örnek', 'oluşmak', 'her', 'bir', 'örüntü', 'seviye', 'KDD', 'için', '100', 'seviye', 'KDD', 'için', '50', 've', 'seviye', 'KDD', 'için', '25', 'örnek', 'düşürmek', 'seviye', 'KDD', 'kullanmak', 'yapmak', 'sınıflamak', 'sonuç', 'aritmi', '100', 'doğru', 'oran', 'ile', 'sınıf', 'görmek', 'bu', 'seviye', 'için', 'gerekli', 'sınıflamak', 'süre', 'saniye', 'olmak', 'el', 'etmek'], ['bu', 'çalışmak', 'elektrokardiyografi', 'aritmi', 'sınıf', 'için', 'gerçek', 'Bulanık', 'kümelemek', 'sinir', 'ağı', 'T2BKSA', 'yapı', 'sunmak', 'Bulanık', 'kümelemek', 'sinir', 'ağı', 'kümelemek', 've', 'sınıf', 'aşama', 'oluşmak', 'kaskat', 'bir', 'yapı', 'T2BKSA', 'yapı', 'aynı', 'sınıf', 'ait', 'örüntü', 'içeri', 'sınıf', 'en', 'iyi', 'temsil', 'etmek', 'örüntü', 'seçmek', 'işlem', 'kapsamak', 'kümelemek', 'aşama', 'Bulanık', 'kümelemek', 'T2BCO', 'algoritma', 'ile', 'gerçek', 'T2BCO', 'kümelemek', 'algoritma', 'kullanmak', 'amaç', 'eğitim', 'örüntü', 'set', 'optimize', 'etmek', 'sinir', 'Ağın', 'sınıf', 'hata', 'düşürmek', 'Bulanık', 'kümelemek', 'algoritma', 'ile', 'her', 'sınıf', 'için', 'ayrı', 'ayrı', 'el', 'etmek', 'küme', 'merkez', 'oluşmak', 'yeni', 'eğitim', 'set', 'yapay', 'sinir', 'Ağın', 'giriş', 'oluşmak', 'yapay', 'sinir', 'ağı', 'geri', 'yayılım', 'algoritma', 'kullanmak', 'eğitmek', 'öneri', 'yapı', 'normal', 'sinüs', 'ritm', 'sinüs', 'bradikardisi', 'sinüs', 'aritmi', 'sağ', 'dal', 'blok', 've', 'sol', 'dal', 'blok', 'sinyal', 'içermek', '5', 'sınıf', 'ait', 'Ekg', 'sinyal', 'sınıf', 'kullanmak', 'çalışmak', 'kullanmak', 'veri', 'Physionet', 'veri', 'taban', 'el', 'etmek', 'ECG', 'Arrhythmia', 'Database', 'e', 'ait', 'veri', 'gerçek', 'uygulamak', 'sonuç', 'öneri', 'T2BKSA', 'yapı', 'Ekg', 'aritmi', '100', 'doğru', 'sınıf', 'oran', 'ile', 'sınıf'], ['Ekg', 'elektro', 'kardiyogram', 'kayıt', 'yazılım', 'taban', 'uzman', 'sistem', 'tarafından', 'yorumlamak', '1960', 'lı', 'yıl', 'dayanmak', 'son', '20', 'yıl', 'bu', 'konu', 'birçok', 'teknik', 'üzeri', 'çalışmak', 'yapmak', 'fakat', 'güç', 'tahmin', 'yetenek', 'olmak', 'inanç', 'sebep', 'medikal', 'tanımak', 'destek', 'sistem', 'uygulamak', 'kullanmak', 'en', 'popüler', 'yöntem', 'YSA', 'yapay', 'sinir', 'ağ', 'olmak', 'literatür', 'öneri', 'YSA', 'model', 'çok', 'karmaşık', 'yazılım', 'taban', 'çözüm', 've', 'bu', 'gerçek', 'zaman', 'çalışmak', 'bu', 'tür', 'yapı', 'donanım', 'gerçeklemek', 'ise', 'ancak', 'paha', 'işlemci', 'üzeri', 'yapmak', 'YSA', 'donanım', 'gerçeklemek', 'taşınmak', 'ucuz', 'cihaz', 'üzeri', 'oluşmak', 'mümkün', 'kılmak', 'için', 'YSA', 'giriş', 'uygulamak', 'Ekg', 'işaret', 'özellik', 'sayı', 'azalmak', 'bu', 'saye', 'daha', 'az', 'sayı', 'bilgi', 'ile', 'daha', 'basit', 'bir', 'mimarî', 'oluşmak', 'mümkün', 'olmak', 'bu', 'çalışmak', 'YSA', 'nın', 'öğrenmek', 'hata', '5', 'gibi', 'kabul', 'etmek', 'bir', 'seviye', 'tutmak', 'TBA', 'temel', 'bileşen', 'analiz', 'yöntem', 'kullanmak', 'Ekg', 'girişmek', 'işaret', 'özellik', 'sayı', 'önem', 'ölçü', 'azalmak', 'bu', 'saye', '8x2x1', 'boyut', 'basit', 'bir', 'Matlab', 'YSA', 'Mode', 'FPGA', 'al ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# %%
def closestwords_tsneplot(model, word):
    word_vectors = np.empty((0,100))
    word_labels = [word]
    close_words = model.wv.most_similar(word)
    word_vectors = np.append(word_vectors, np.array([model.wv[word]]), axis = 0)
    
    for w, _ in close_words:
        word_labels.append(w)
        word_vectors = np.append(word_vectors, np.array([model.wv[w]]), axis = 0)
    tsne = TSNE(random_state = 0)
    Y = tsne.fit_transform(word_vectors)
    x_coords = Y[:,0]
    y_coords = Y[:,1]
    plt.scatter(x_coords, y_coords)
    
    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy = (x,y), xytext = (5, -2), textcoords = "offset points")
    
    plt.show()

# %%
closestwords_tsneplot(model2,"Türkiye")
